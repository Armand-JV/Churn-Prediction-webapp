# %% [markdown]
# # Phase 3: Model Comparison & Champion Selection
# ## Telco Customer Churn Prediction Project
#
# **Goal**: Compare all models trained in Phase 2 and select the best one for deployment in the DASH web application.
#
# Models evaluated:
# - Logistic Regression (baseline)
# - Random Forest
# - XGBoost
# - LightGBM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import os
from pathlib import Path

from sklearn.metrics import (
    f1_score, roc_auc_score, average_precision_score,
    classification_report, confusion_matrix
)
import shap
import warnings
warnings.filterwarnings('ignore')

# Config
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
np.random.seed(42)
print("✅ Libraries loaded for model comparison")
# Out:
# ✅ Libraries loaded for model comparison

# %%
# Load processed test data + feature names
preprocessor = joblib.load('../src/models/preprocessor.joblib')
feature_names = preprocessor.get_feature_names_out()

X_test = pd.read_csv('../data/processed/X_test_processed.csv', header=0)
X_test.columns = feature_names

y_test = pd.read_csv('../data/processed/y_test.csv').iloc[:, 0].astype(int)

print(f"Test set: {X_test.shape} | Churn rate: {y_test.mean():.1%}")
# Out:
# Test set: (1409, 39) | Churn rate: 26.5%

# %%
# Load all trained models
models = {}
model_paths = {
    'Logistic Regression': '../src/models/logistic_regression.joblib',
    'Random Forest': '../src/models/random_forest.joblib',
    'XGBoost': '../src/models/xgboost.joblib',           # uncomment when you have them
    'LightGBM': '../src/models/lightgbm.joblib'
}

for name, path in model_paths.items():
    if os.path.exists(path):
        models[name] = joblib.load(path)
        print(f"✅ Loaded {name}")
    else:
        print(f"⚠️  Model not found: {path}")

print(f"\nLoaded {len(models)} models for comparison.")
# Out:
# ✅ Loaded Logistic Regression
# ✅ Loaded Random Forest
# ✅ Loaded XGBoost
# ✅ Loaded LightGBM
#
# Loaded 4 models for comparison.

# %%
# Evaluate all models
results = []

for name, model in models.items():
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1]
    
    f1 = f1_score(y_test, y_pred)
    roc = roc_auc_score(y_test, y_prob)
    pr = average_precision_score(y_test, y_prob)
    
    # Recall on churn class (important for business)
    report = classification_report(y_test, y_pred, output_dict=True, target_names=['No Churn', 'Churn'])
    churn_recall = report['Churn']['recall']
    
    results.append({
        'Model': name,
        'F1-Score': round(f1, 4),
        'ROC-AUC': round(roc, 4),
        'PR-AUC': round(pr, 4),
        'Churn_Recall': round(churn_recall, 4)
    })

# Create comparison DataFrame
comparison_df = pd.DataFrame(results)
comparison_df = comparison_df.sort_values(by='F1-Score', ascending=False)

print("=== Model Comparison Table ===")
display(comparison_df)

# Save comparison
os.makedirs('../data/processed', exist_ok=True)
comparison_df.to_csv('../data/processed/model_comparison.csv', index=False)
# Out:
# === Model Comparison Table ===
#                  Model  F1-Score  ROC-AUC  PR-AUC  Churn_Recall
# 2              XGBoost    0.6347   0.8479  0.6575        0.8128
# 1        Random Forest    0.6338   0.8423  0.6520        0.7567
# 3             LightGBM    0.6267   0.8423  0.6518        0.8102
# 0  Logistic Regression    0.6188   0.8387  0.6346        0.7834

# %%
# Visual comparison

# Ensure directories exist
Path('../src/figures').mkdir(parents=True, exist_ok=True)

fig, axes = plt.subplots(2, 2, figsize=(15, 10))
metrics = ['F1-Score', 'ROC-AUC', 'PR-AUC', 'Churn_Recall']

for i, metric in enumerate(metrics):
    ax = axes[i//2, i%2]
    sns.barplot(data=comparison_df, x='Model', y=metric, ax=ax, palette='viridis')
    ax.set_title(f'Comparison by {metric}')
    ax.set_ylim(0, 1)
    for container in ax.containers:
        ax.bar_label(container, fmt='%.3f')

plt.tight_layout()
plt.savefig('../src/figures/model_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Select champion (highest F1-score)
champion_name = comparison_df.iloc[0]['Model']
champion_model = models[champion_name]

print(f"🏆 CHAMPION MODEL: {champion_name}")
print(f"F1-Score: {comparison_df.iloc[0]['F1-Score']:.4f}")

# Save champion for DASH deployment
Path('../src/models').mkdir(parents=True, exist_ok=True)
joblib.dump(champion_model, '../src/models/champion_model.joblib')
joblib.dump(feature_names, '../src/models/feature_names.joblib')

print("✅ Champion model saved as 'champion_model.joblib' – ready for DASH web app!")
# Out:
# 🏆 CHAMPION MODEL: XGBoost
# F1-Score: 0.6347
# ✅ Champion model saved as 'champion_model.joblib' – ready for DASH web app!

# %%
# SHAP Analysis on Champion (if tree-based)
if champion_name in ['Random Forest', 'XGBoost', 'LightGBM']:
    print(f"\nGenerating SHAP explanations for {champion_name}...")
    
    # ── FIX: XGBoost ≥ 2.x stores base_score as "[5E-1]" (with brackets)
    # in its internal config, which causes float() to raise ValueError inside
    # shap.TreeExplainer.  We patch the config string before handing the
    # booster to SHAP so the brackets are stripped.
    if champion_name == 'XGBoost':
        import json
        import types

        booster = champion_model.get_booster()
        config = json.loads(booster.save_config())
        
        param = config['learner']['learner_model_param']
        param['base_score'] = param['base_score'].strip('[]')
        booster.load_config(json.dumps(config))
        
        # Verify the patch actually took
        config_check = json.loads(booster.save_config())
        print("base_score after patch:", 
            config_check['learner']['learner_model_param']['base_score'])
        
        # Monkey-patch get_booster() so SHAP gets our patched booster
        patched_booster = booster
        champion_model.get_booster = types.MethodType(
            lambda self: patched_booster, champion_model
        )
        model_for_shap = champion_model
    
    print(f"champion_name repr: {repr(champion_name)}")
    
    explainer = shap.TreeExplainer(model_for_shap)
    shap_values = explainer.shap_values(X_test)
    
    # For binary classification: select the Churn class (index 1)
    if isinstance(shap_values, list):           # RF and LightGBM return list
        shap_values_churn = shap_values[1]
    else:                                       # XGBoost returns array directly
        shap_values_churn = shap_values
    
    # Summary plot (global feature importance)
    plt.figure(figsize=(12, 8))
    shap.summary_plot(shap_values_churn, X_test, plot_type="bar", show=False)
    plt.title(f'Global SHAP Feature Importance - {champion_name}')
    plt.tight_layout()
    plt.savefig('../src/figures/shap_global_importance.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    # Detailed beeswarm plot
    plt.figure(figsize=(12, 8))
    shap.summary_plot(shap_values_churn, X_test, show=False)
    plt.title(f'SHAP Summary Plot - {champion_name}')
    plt.tight_layout()
    plt.savefig('../src/figures/shap_summary.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    print("✅ SHAP plots saved.")
# Out:
# Generating SHAP explanations for XGBoost...
# champion_name repr: 'XGBoost'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 27
#      23     model_for_shap = champion_model
#      25 print(f"champion_name repr: {repr(champion_name)}")
# ---> 27 explainer = shap.TreeExplainer(model_for_shap)
#      28 shap_values = explainer.shap_values(X_test)
#      30 # For binary classification: select the Churn class (index 1)
#
# File c:\Users\ajver\Documents\GitHub\CYO-Project-MLG382\venv311\Lib\site-packages\shap\explainers\_tree.py:278, in TreeExplainer.__init__(self, model, data, model_output, feature_perturbation, feature_names, approximate, link, linearize_link)
#     276 self.feature_perturbation = feature_perturbation
#     277 self.expected_value = None
# --> 278 self.model = TreeEnsemble(model, self.data, self.data_missing, model_output)
#     279 self.model_output = model_output
#     280 # self.model_output = self.model.model_output # this allows the TreeEnsemble to translate model outputs types by how it loads the model
#     281
#     282 # check for unsupported combinations of feature_perturbation and model_outputs
#
# File c:\Users\ajver\Documents\GitHub\CYO-Project-MLG382\venv311\Lib\site-packages\shap\explainers\_tree.py:1261, in TreeEnsemble.__init__(self, model, data, data_missing, model_output)
#    1259 self.input_dtype = np.float32
#    1260 self.original_model = model.get_booster()
# -> 1261 self._set_xgboost_model_attributes(
#    1262     data,
#    1263     data_missing,
#    1264     objective_name_map,
#    1265     tree_output_name_map,
#    1266 )
#    1268 if self.model_output == "predict_proba":
#    1269     if self.num_stacked_models == 1:
#    1270         # with predict_proba we need to double the outputs to match
#
# File c:\Users\ajver\Documents\GitHub\CYO-Project-MLG382\venv311\Lib\site-packages\shap\explainers\_tree.py:1506, in TreeEnsemble._set_xgboost_model_attributes(self, data, data_missing, objective_name_map, tree_output_name_map)
#    1498 def _set_xgboost_model_attributes(
#    1499     self,
#    1500     data,
#    (...)   1503     tree_output_name_map,
#    1504 ):
#    1505     self.model_type = "xgboost"
# -> 1506     loader = XGBTreeModelLoader(self.original_model)
#    1508     self.trees = loader.get_trees(data=data, data_missing=data_missing)
#    1509     self.base_offset = loader.base_score
#
# File c:\Users\ajver\Documents\GitHub\CYO-Project-MLG382\venv311\Lib\site-packages\shap\explainers\_tree.py:2104, in XGBTreeModelLoader.__init__(self, xgb_model)
#    2102 self.n_trees_per_iter = int(diff[0])
#    2103 self.n_targets = n_targets
# -> 2104 self.base_score = float(learner_model_param["base_score"])
#    2105 assert self.n_trees_per_iter > 0
#    2107 self.name_obj = objective["name"]
#
# ValueError: could not convert string to float: '[5E-1]'

# %% [markdown]
# ## Summary & Recommendations for Phase 4 (DASH Web App)
#
# **Key Takeaways:**
# - **Champion Model**: XGBoost
# - Best F1-Score: 0.6347
# - Churn Recall: champion_model.joblib (critical for business)
